# %%
import random
import matplotlib.pyplot as plt

# %%
import data
from utils.plotting import draw_chars

dataset = data.raw_chars()
print("Loaded {} characters".format(len(dataset)))
# Out:
# Loaded 11640 characters

# %%
sample = random.sample(dataset, 100)

plt.figure(figsize=(10, 14))
draw_chars(sample)
